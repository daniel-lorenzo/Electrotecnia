# %% [markdown]
# # Ejercicios de clase - Thevenin
# __UNLZ - Facultad de Ingeniería__
# __Electrotecnia__
# __Alumno:__ Daniel Antonio Lorenzo

# %% [markdown]
# ## Problema N°2
# Obtener el equivalente de Thevenin (entre los puntos a y b) y calcular la corriente que circularía si, en estos terminales, se coloca una resistencia de $30 \, \Omega$ $(R_c)$.

# %% [markdown]
# ![tp3e2.png](data:image/png;base64,...)

# %% [markdown]
# ### Solución

# %% [markdown]
# __Cálculo de $Z_{th}$__
#
# 1) $Z_0 || Z_1$; siendo $Z_0 = 0 + j0 = 0e^{-j0^\circ}$

# %% [markdown]
# $$ \frac{Z_0 Z_1}{Z_0 + Z_1} = \frac{0e^{j0} \cdot 111,8e^{j63,43^\circ}}{(0 + j0) + (50 + j100)} = 0 $$

# %% [markdown]
# ![tp3e2-1.png](data:image/png;base64,...)

# %% [markdown]
# 2) $Z_2 || Z_3$

# %% [markdown]
# $$ \frac{Z_2 Z_3}{Z_2 + Z_3} = \frac{111,8e^{j63,43} \cdot 50e^{-j90^\circ}}{(50 + j100) + (0 - j50)} $$

# %% [markdown]
# $$
# = 79,06e^{-j71,57^\circ} \, \Omega
# $$

# %% [markdown]
# $$
# \rightarrow (25 - j75) \, \Omega
# $$

# %% [markdown]
# ![tp3e2-2.png](data:image/png;base64,...)

# %% [markdown]
# 3) $(Z_2 || Z_3) + Z_4$

# %% [markdown]
# ![tp3e2-3.png](data:image/png;base64,...)

# %% [markdown]
# $$ (25 - j75) + (25 + j0) = (50 - j75) \, \Omega $$

# %% [markdown]
# <div class="alert-info"><strong>Por lo tanto</strong>
# $$ Z_{th} = (50 - j75) \, \Omega $$
#     </div>

# %% [markdown]
# $$
# \rightarrow \quad 90,14e^{-j56,31^\circ} \, \Omega
# $$

# %% [markdown]
# __Cálculo de $V_{th}$__

# %% [markdown]
# $$ V_{th} = V_{AB} = V_{Z_3} $$

# %% [markdown]
# ![tp3e2-4.png](data:image/png;base64,...)

# %% [markdown]
# 1) $Z_3 + Z_2$
# $$ (0 - j50) + (50 + j100) = 50 + j50 \, \Omega$$

# %% [markdown]
# $$
# \rightarrow 70,71e^{j45^\circ} \, \Omega
# $$

# %% [markdown]
# ![tp3e2-5.png](data:image/png;base64,...)

# %% [markdown]
# 2) $(Z_4 + Z_3) \, || Z_1$
# $$ \frac{70,71e^{j45^\circ} \cdot 111,8e^{j63,43^\circ}}{(50 + j50) + (50 + j100)} = 43,85e^{j52,13^\circ} \, \Omega $$

# %% [markdown]
# Por lo tanto
# $$ Z_{eq} = 43,85e^{j52,13^\circ} \, \Omega $$

# %% [markdown]
# Cálculo $I_t$

# %% [markdown]
# ![tp3e2-6.png](data:image/png;base64,...)

# %% [markdown]
# $$ I_t = \frac{V}{Z_{eq}} = \frac{220e^{j0^\circ}}{43,85e^{51,13^\circ}} = 5,02e^{-j52,13^\circ} \, \mathrm{A} $$

# %% [markdown]
# $$
# \rightarrow (3,08 - j3,96) \, \mathrm{A}
# $$

# %% [markdown]
# Además
# $$ I_2 = I_t - I_1 $$

# %% [markdown]
# Entonces
# $$ I_1 = \frac{U}{Z_1} = \frac{220e^{j0^\circ}}{111,8e^{j63,43^\circ}} = 1,97e^{-j63,43^\circ} \, \mathrm{A} $$

# %% [markdown]
# $$
# \rightarrow (0,88 - j1,76) \, \mathrm{A}
# $$

# %% [markdown]
# Cálculo de $I_2$
# $$ I_2 = I_t - I_2 = (2,20 - j2,20) \, \mathrm{A} $$

# %% [markdown]
# $$
# \rightarrow 3,11e^{-j45^\circ} \, \mathrm{A}
# $$

# %% [markdown]
# <div class="alert-info"><strong>Por lo tanto</strong>
# $$ V_{th} = V_{AB} = V_{Z_3} = I_2 Z_3 = 155,56e^{-j135^\circ} \, \mathrm{V} $$
#     </div>

# %% [markdown]
# ![tp3e2-7.png](data:image/png;base64,...)

# %% [markdown]
# <div class="alert-info"><strong>Cálculo de $I_{RC}$</strong>
# $$ I_{RC} = \frac{V_{th}}{Z_{th} + R_c} = 1,42e^{-j91,85^\circ} \, \mathrm{A} $$
#     </div>

# %% [markdown]
# ### Usando python para calcular (opcional)

# %%
import math, cmath

# %%
# Datos
Z1 = 50+100j
Z2 = Z1
Z3 = 0-50j
Z4 = 25+0j
U = 220+0j
Rc = 30

# %%
# Cálculo de Zth
#1)   Z0 || Z1 ; siendo Z0 = 0 + 0j
Z0 = 0
ans1 = (Z0*Z1)/(Z0 + Z3)

#2)   Z2 || Z3
ans2 = (Z2*Z3)/(Z2+Z3)

#3)   (Z2 || Z3) + Z4
Zth = ans2 + Z4
Zthpol = cmath.polar(Zth)

# Cálculo de Zeq = (Z2 + Z3) || Z1
Zeq = ((Z2 + Z3)*Z1)/(Z1 + Z2 + Z3)

# Cálculo de It
It = U/Zeq
I1 = U/Z1
I2 = It - I1

# Cálculo de Vth
Vth = I2*Z3
Vth_pol = cmath.polar(Vth)

# Cálculo de I_rc
I_rc = Vth/(Zth + Rc)
I_rcpol = cmath.polar(I_rc)

# %%
#@title Imprime resultados:
print('Resultados:')
print('-----------------------------------------')
print('Zth = (%.2f < %.2f°) Ohm'%(Zthpol[0], math.degrees(Zthpol[1]) ) )
print('Zth = {:.2f} Ohm'.format(Zth))
print('-----------------------------------------')
print('Vth = (%.2f < %.2f°) V'%(Vth_pol[0], math.degrees(Vth_pol[1]) ))
print('Vth = {:.2f} V'.format(Vth))
print('-----------------------------------------')
print('I_rc = (%.2f < %.2f°) A'%(I_rcpol[0], math.degrees(I_rcpol[1]) ))
print('I_rc = {:.4f} A'.format(I_rc))
print('-----------------------------------------')
# Out:
# Resultados:
# -----------------------------------------
# Zth = (90.14 < -56.31°) Ohm
# Zth = 50.00-75.00j Ohm
# -----------------------------------------
# Vth = (155.56 < -135.00°) V
# Vth = -110.00-110.00j V
# -----------------------------------------
# I_rc = (1.42 < -91.85°) A
# I_rc = -0.0457-1.4179j A
# -----------------------------------------
